# %%
import sys
print(sys.version)
from difflib import SequenceMatcher
import numpy as np
# Out:
# 3.10.8 (tags/v3.10.8:aaaf517, Oct 11 2022, 16:50:30) [MSC v.1933 64 bit (AMD64)]

# %%
import pandas as pd
master_csv = pd.read_csv(filepath_or_buffer="jidosyo_gakusan_master.csv", encoding="utf8", sep=",")

# %%
master_csv.head(10)
# Out:
#              JAN                           SHOSINM KANSU  ITMCD  DAIGENRECD  \
# 0  9784839982423                        たのしいこといっぱい   NaN   1076          16
# 1  9784796873529           かむもかまぬも神だのみ　めちゃヘンな早口ことば   NaN   1076          16
# 2  9784796880428                          移動するものたち   NaN   1076          16
# 3  9784800590039                １２歳までに知っておきたい語彙力図鑑   NaN   1076          16
# 4  9784800590558                           かたづけできた   NaN   1076          16
# 5  9784866631745     宇宙のふしぎ３６６　１日１ページで小学生から頭がよくなる！   NaN   1076          16
# 6  9784866631905                         地球のふしぎ３６６   NaN   1076          16
# 7  9784866515113                うんこドリル　てんつなぎ　４・５さい   NaN   1076          19
# 8  9784866515403  うんこドリル　数・たんい・図形小学３年生　日本一楽しい学習ドリル   NaN   1076          19
# 9  9784866515175           うんこ夏ドリル　５さい　日本一楽しい学習ドリル   NaN   1076          19
#
#    CHUGENRECD  SHOGENRECD  SIKIRIBANCD ITMNM DAIGENRENM  ... SIKIRIBANNM  \
# 0           7           1           92    書籍        児童書  ...        国内絵本
# 1          61           1           91    書籍        児童書  ...     その他実用百科
# 2           7           3           92    書籍        児童書  ...        海外絵本
# 3          71           1            3    書籍        児童書  ...          国語
# 4          11           3            3    書籍        児童書  ...      せいかつ絵本
# 5          71           1          411    書籍        児童書  ...     理科　星・宇宙
# 6          71           1            4    書籍        児童書  ...          理科
# 7           1           1            1    書籍      学習参考書  ...       幼児ドリル
# 8           5           1           51    書籍      学習参考書  ...      うんこドリル
# 9           1           1            1    書籍      学習参考書  ...       幼児ドリル
#
#    CHOSHANM SHPNSHACD         SHPNSHANM  SAKUHINCD  \
# 0       NaN      8399            マイナビ出版   43390473
# 1      大谷健太      7968     小学館集英社プロダクション   43378399
# 2  イッサ・ワタナベ      7968     小学館集英社プロダクション   43378400
# 3       齋藤孝      8005  日本能率協会マネジメントセンター   43318183
# 4     北川真理子      8005  日本能率協会マネジメントセンター   43372108
# 5      左巻健男     86663             きずな出版   43344054
# 6      左巻健男     86663             きずな出版   43380837
# 7      古屋雄作     86651               文響社   43323041
# 8      古屋雄作     86651               文響社   43335814
# 9      古屋雄作     86651               文響社   43331528
#
#                           SAKUHINNM          SOSHONM HATUBAIYMD ANNUAL_SALES  \
# 0                        たのしいこといっぱい              NaN   20230131         16.0
# 1           かむもかまぬも神だのみ　めちゃヘンな早口ことば              NaN   20221222        460.0
# 2                          移動するものたち              NaN   20221222        101.0
# 3                １２歳までに知っておきたい語彙力図鑑              NaN   20220330       6822.0
# 4                           かたづけできた  モンテッソーリのせいかつえほん   20221202        161.0
# 5     宇宙のふしぎ３６６　１日１ページで小学生から頭がよくなる！              NaN   20220721       1406.0
# 6                         地球のふしぎ３６６              NaN   20221208        412.0
# 7                うんこドリル　てんつなぎ　４・５さい              NaN   20220512       2325.0
# 8  うんこドリル　数・たんい・図形小学３年生　日本一楽しい学習ドリル         うんこドリル算数   20220711       1188.0
# 9           うんこ夏ドリル　５さい　日本一楽しい学習ドリル       うんこドリルシリーズ   20220609       3716.0
#
#        SUBLABEL
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7  幼児 ドリル 4歳 5歳
# 8   小学生 ドリル 3年生
# 9     幼児 ドリル 5歳
#
# [10 rows x 22 columns]

# %%
df = pd.read_csv(filepath_or_buffer="child_series_moto_児童書_shpnshanm_seriesnm.csv", encoding="utf8", sep=",")
print(df)
# Out:
#      SHPNSHANM      SERIESNM
# 0       あいうえお館   ウルトラかいじゅう絵本
# 1       あいうえお館        ウルトラマン
# 2        あかね書房     くまたくんのえほん
# 3        あかね書房  かばくん・くらしのえほん
# 4        あかね書房   あかね新えほんシリーズ
# ...        ...           ...
# 2544    ＰＨＰ研究所   パオちゃんの絵本第４集
# 2545    ＰＨＰ研究所   パオちゃんの絵本第１集
# 2546    ＰＨＰ研究所      パオちゃんの絵本
# 2547    ＴＯブックス       本好きの下剋上
# 2548    ＷＡＶＥ出版        パディントン
#
# [2549 rows x 2 columns]

# %%
seriesnm = {}
shpnshanm = ''
shpnshanm = set(df['SHPNSHANM'].values.tolist())
for l in shpnshanm:
    seriesnm[l] = []

for index, row in df.iterrows():
    seriesnm[row['SHPNSHANM']].append(row['SERIESNM'])

# %%
def check_inputname_in_seriesnm(input_name, shpnshanm):
    if input_name in seiriesnm[shpnshanm]:
        return seriesnm[shpnshanm]
    else:
        return ''

# %%
# 完全に含まれているかを確認
# SHOSINM, SIKIRIBANNM, SOSHONM, SUBLABEL

complete_seriesnm_candidate_list = []
for index, row in master_csv.iterrows():
    if pd.isnull(row['SERIESNM']):
        complete_seriesnm_candidate_list.append(check_inputname_in_seriesnm(row['SHOSINM'], row['SHPNSHANM']))
    else:
        complete_seriesnm_candidate_list.append('')

print(complete_seriesnm_candidate_list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SERIESNM'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [8], line 6
#       4 complete_seriesnm_candidate_list = []
#       5 for index, row in master_csv.iterrows():
# ----> 6     if pd.isnull(row['SERIESNM']):
#       7         complete_seriesnm_candidate_list.append(check_inputname_in_seriesnm(row['SHOSINM'], row['SHPNSHANM']))
#       8     else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'SERIESNM'

# %%
def extract_seriesnm_candidate(input_name, shpnshanm):
    seriesnm_candidate = ''
    max_match_size = 0
    
    if not shpnshanm in seriesnm:
        return
    
    for sn in seriesnm[shpnshanm]:
        match = SequenceMatcher(None, input_name, sn).find_longest_match(0, len(input_name), 0, len(sn))

        if max_match_size < match.size and match.size >= 6:
            seriesnm_candidate = sn
            max_match_size = match.size
    
    return seriesnm_candidate

# %%
seriesnm_candidate_list = []
for index, row in master_csv.iterrows():
    if pd.isnull(row['SERIESNM']):
        seriesnm_candidate_list.append(extract_seriesnm_candidate(row['SHOSINM'], row['SHPNSHANM']))
    else:
        seriesnm_candidate_list.append('')

print(seriesnm_candidate_list)
